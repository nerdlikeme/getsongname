# %% [markdown]
# <a href="https://colab.research.google.com/github/nerdlikeme/getsongname/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5931, done.
# remote: Total 5931 (delta 0), reused 0 (delta 0), pack-reused 5931
# Receiving objects: 100% (5931/5931), 6.34 MiB | 23.36 MiB/s, done.
# Resolving deltas: 100% (3925/3925), done.

# %%
cd darknet
# Out:
# /content/darknet

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-02-13 15:18:32--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  38.9MB/s    in 4.4s
#
# 2021-02-13 15:18:37 (35.3 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/MyDrive/google colab")

# %%
# %cp -av images /content/darknet/data/
# Out:
# 'images' -> '/content/darknet/data/images'
# 'images/DIBP3-8VwAAGcVF_jpg.rf.bf02bad3ceb2e0a7f75442e2ebb7dd31.jpg' -> '/content/darknet/data/images/DIBP3-8VwAAGcVF_jpg.rf.bf02bad3ceb2e0a7f75442e2ebb7dd31.jpg'
# 'images/image14_jpeg.rf.c7800758c392239b4af8f53579d83694.jpg' -> '/content/darknet/data/images/image14_jpeg.rf.c7800758c392239b4af8f53579d83694.jpg'
# 'images/lostinwashington0000casp_jpg.rf.c120f4d51050d015f0f1ecc08471db40.jpg' -> '/content/darknet/data/images/lostinwashington0000casp_jpg.rf.c120f4d51050d015f0f1ecc08471db40.jpg'
# 'images/nationalgeograph0000unse_b5h1_jpg.rf.c5d9e484579f5160c42b13cf2ec512f2.jpg' -> '/content/darknet/data/images/nationalgeograph0000unse_b5h1_jpg.rf.c5d9e484579f5160c42b13cf2ec512f2.jpg'
# 'images/keystohappiness0000whit_jpg.rf.bde3ea2e8bd28ab22019a578c54751df.jpg' -> '/content/darknet/data/images/keystohappiness0000whit_jpg.rf.bde3ea2e8bd28ab22019a578c54751df.jpg'
# ...

# %%
# %cp -av labels /content/darknet/data/
# Out:
# 'labels/51heehLetSL-_SX338_BO1204203200__jpg.rf.5cff6faa6ff5acbc40c672c3eb0eb2ad.txt' -> '/content/darknet/data/labels/51heehLetSL-_SX338_BO1204203200__jpg.rf.5cff6faa6ff5acbc40c672c3eb0eb2ad.txt'
# 'labels/136493360_438159527594039_8763854695455462203_n_jpg.rf.1193752682c4e382a1ee1e00bc2ae2dc.txt' -> '/content/darknet/data/labels/136493360_438159527594039_8763854695455462203_n_jpg.rf.1193752682c4e382a1ee1e00bc2ae2dc.txt'
# 'labels/in_the_shadow_of_blackbirds_by_cat_winters_1528812731_a07a9a61_jpg.rf.f97271929fccc941a1aaf535c3306a6a.txt' -> '/content/darknet/data/labels/in_the_shadow_of_blackbirds_by_cat_winters_1528812731_a07a9a61_jpg.rf.f97271929fccc941a1aaf535c3306a6a.txt'
# 'labels/de35anslagepresc0000benn_jpg.rf.591d0c6cedb1e0e3e945db4925f4fb75.txt' -> '/content/darknet/data/labels/de35anslagepresc0000benn_jpg.rf.591d0c6cedb1e0e3e945db4925f4fb75.txt'
# ...
